# %%
import os
os.getcwd()
# Out:
# 'd:\\iNeuron\\ML_projects\\Big_mart_sales\\research'

# %%
os.chdir('../')
os.getcwd()
# Out:
# 'd:\\iNeuron\\ML_projects\\Big_mart_sales'

# %%
from BigMartSales.config import Configuration

# %%
confi = Configuration('configs/config.yaml')
# Out:
# [2022-11-24 13:14:55,353]^;INFO^;26^;common.py^;read_yaml()^;yaml file: configs\config.yaml loaded successfully
# [2022-11-24 13:14:55,354]^;INFO^;201^;__init__.py^;get_training_pipeline_config()^;Training pipleine config: TrainingPipelineConfig(artifact_dir='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact')

# %%
from BigMartSales.pipeline import Pipeline

# %%
Pipeline(confi).run()
# Out:
# [2022-11-24 13:14:56,057]^;INFO^;126^;__init__.py^;run_pipeline()^;Pipeline starting.
# [2022-11-24 13:14:56,058]^;INFO^;141^;__init__.py^;run_pipeline()^;Pipeline experiment: Experiment(experiment_id='be7cc610-421c-4d84-abdb-4eb0bae5c893', initialization_timestamp='2022-11-24-13-14-54', artifact_time_stamp='2022-11-24-13-14-54', running_status=True, start_time=datetime.datetime(2022, 11, 24, 13, 14, 56, 58078), stop_time=None, execution_time=None, message='Pipeline has been started.', experiment_file_path='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\experiment\\experiment.csv', accuracy=None, is_model_accepted=None)
# [2022-11-24 13:14:56,072]^;INFO^;55^;__init__.py^;get_data_ingestion_config()^;DataIngestionConfig: DataIngestionConfig(dataset_download_url='https://github.com/ajaharleo/kaggle_datasets/blob/main/Big_mart_sales.zip?raw=true', zip_download_dir='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_ingestion\\2022-11-24-13-14-54\\zip_data', raw_data_dir='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_ingestion\\2022-11-24-13-14-54\\raw_data', ingested_train_dir='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_ingestion\\2022-11-24-13-14-54\\ingested_data\\train', ingested_test_dir='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_ingestion\\2022-11-24-13-14-54\\ingested_data\\test', ingested_dir='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_ingestion\\2022-11-24-13-14-54\\ingested_data')
# [2022-11-24 13:14:56,073]^;INFO^;19^;data_ingestion.py^;__init__()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Data Ingestion Started <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:14:56,074]^;INFO^;33^;data_ingestion.py^;download_data()^;Downloading file from : https://github.com/ajaharleo/kaggle_datasets/blob/main/Big_mart_sales.zip?raw=true into : d:\iNeuron\ML_projects\Big_mart_sales\sales\artifact\data_ingestion\2022-11-24-13-14-54\zip_data
# [2022-11-24 13:14:57,437]^;INFO^;43^;data_ingestion.py^;download_data()^;File downloaded successfully  d:\iNeuron\ML_projects\Big_mart_sales\sales\artifact\data_ingestion\2022-11-24-13-14-54\zip_data
# [2022-11-24 13:14:57,439]^;INFO^;58^;data_ingestion.py^;extract_data()^;Extracting zip file d:\iNeuron\ML_projects\Big_mart_sales\sales\artifact\data_ingestion\2022-11-24-13-14-54\zip_data into dir d:\iNeuron\ML_projects\Big_mart_sales\sales\artifact\data_ingestion\2022-11-24-13-14-54\raw_data
# None
# [2022-11-24 13:14:57,453]^;INFO^;68^;data_ingestion.py^;extract_data()^;>>>>>>>>>>>>>>>>>>>> Extraction completed <<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:14:57,455]^;INFO^;83^;data_ingestion.py^;split_data_as_train_test()^;Reading csv file: [d:\iNeuron\ML_projects\Big_mart_sales\sales\artifact\data_ingestion\2022-11-24-13-14-54\raw_data\data.csv]
# [2022-11-24 13:14:57,476]^;INFO^;86^;data_ingestion.py^;split_data_as_train_test()^;Splitting data into train and test with test data ration = 0.2
# [2022-11-24 13:14:57,481]^;INFO^;97^;data_ingestion.py^;split_data_as_train_test()^;Exporting training datset to file: [d:\iNeuron\ML_projects\Big_mart_sales\sales\artifact\data_ingestion\2022-11-24-13-14-54\ingested_data\train\data.csv]
# [2022-11-24 13:14:57,547]^;INFO^;101^;data_ingestion.py^;split_data_as_train_test()^;Exporting test dataset to file: [d:\iNeuron\ML_projects\Big_mart_sales\sales\artifact\data_ingestion\2022-11-24-13-14-54\ingested_data\test\data.csv]
# [2022-11-24 13:14:57,566]^;INFO^;115^;data_ingestion.py^;split_data_as_train_test()^;data_ingestion_artifact : [DataIngestionArtifact(train_file_path='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_ingestion\\2022-11-24-13-14-54\\ingested_data\\train\\data.csv', test_file_path='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_ingestion\\2022-11-24-13-14-54\\ingested_data\\test\\data.csv', is_ingested=True, message='Data ingestion completed successfully.')]
# [2022-11-24 13:14:57,568]^;INFO^;136^;data_ingestion.py^;__del__()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Data Ingestion completed <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# [2022-11-24 13:14:57,569]^;INFO^;89^;__init__.py^;get_data_validation_config()^;DataValidationConfig: [DataValidationConfig(schema_file_path='d:\\iNeuron\\ML_projects\\Big_mart_sales\\configs\\schema.yaml', report_file_path='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_validation\\2022-11-24-13-14-54\\report.json', report_page_file_path='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_validation\\2022-11-24-13-14-54\\report.html')]
# [2022-11-24 13:14:57,571]^;INFO^;22^;data_validation.py^;__init__()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> DataValidation started <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# [2022-11-24 13:14:57,582]^;INFO^;26^;common.py^;read_yaml()^;yaml file: d:\iNeuron\ML_projects\Big_mart_sales\configs\schema.yaml loaded successfully
# [2022-11-24 13:14:57,585]^;INFO^;49^;data_validation.py^;do_train_test_files_exist()^;IS train and test File Exists? -> True
# [2022-11-24 13:14:57,593]^;INFO^;26^;common.py^;read_yaml()^;yaml file: d:\iNeuron\ML_projects\Big_mart_sales\configs\schema.yaml loaded successfully
# [2022-11-24 13:14:57,621]^;INFO^;64^;data_validation.py^;validation_dataset_schema()^;Checking no. of columns in train and test dataset
# [2022-11-24 13:14:57,622]^;INFO^;68^;data_validation.py^;validation_dataset_schema()^;No. of columns are same in train and test dataset and in schema file.
# [2022-11-24 13:14:57,622]^;INFO^;69^;data_validation.py^;validation_dataset_schema()^;Checking columns names
# [2022-11-24 13:14:57,624]^;INFO^;76^;data_validation.py^;validation_dataset_schema()^;Train and test dataset have column required in schema file
# [2022-11-24 13:14:57,625]^;INFO^;77^;data_validation.py^;validation_dataset_schema()^;Checking the datatypes of all columns
# [2022-11-24 13:14:57,627]^;INFO^;80^;data_validation.py^;validation_dataset_schema()^;Column 'Item_Identifier' has correct datatype in both train and test dataset.
# [2022-11-24 13:14:57,629]^;INFO^;80^;data_validation.py^;validation_dataset_schema()^;Column 'Item_Weight' has correct datatype in both train and test dataset.
# [2022-11-24 13:14:57,630]^;INFO^;80^;data_validation.py^;validation_dataset_schema()^;Column 'Item_Fat_Content' has correct datatype in both train and test dataset.
# [2022-11-24 13:14:57,631]^;INFO^;80^;data_validation.py^;validation_dataset_schema()^;Column 'Item_Visibility' has correct datatype in both train and test dataset.
# [2022-11-24 13:14:57,633]^;INFO^;80^;data_validation.py^;validation_dataset_schema()^;Column 'Item_Type' has correct datatype in both train and test dataset.
# [2022-11-24 13:14:57,636]^;INFO^;80^;data_validation.py^;validation_dataset_schema()^;Column 'Item_MRP' has correct datatype in both train and test dataset.
# [2022-11-24 13:14:57,637]^;INFO^;80^;data_validation.py^;validation_dataset_schema()^;Column 'Outlet_Identifier' has correct datatype in both train and test dataset.
# [2022-11-24 13:14:57,638]^;INFO^;80^;data_validation.py^;validation_dataset_schema()^;Column 'Outlet_Establishment_Year' has correct datatype in both train and test dataset.
# [2022-11-24 13:14:57,640]^;INFO^;80^;data_validation.py^;validation_dataset_schema()^;Column 'Outlet_Size' has correct datatype in both train and test dataset.
# [2022-11-24 13:14:57,642]^;INFO^;80^;data_validation.py^;validation_dataset_schema()^;Column 'Outlet_Location_Type' has correct datatype in both train and test dataset.
# [2022-11-24 13:14:57,643]^;INFO^;80^;data_validation.py^;validation_dataset_schema()^;Column 'Outlet_Type' has correct datatype in both train and test dataset.
# [2022-11-24 13:14:57,644]^;INFO^;80^;data_validation.py^;validation_dataset_schema()^;Column 'Item_Outlet_Sales' has correct datatype in both train and test dataset.
# [2022-11-24 13:14:57,645]^;INFO^;84^;data_validation.py^;validation_dataset_schema()^;Checking the domain values of categorical columns
# [2022-11-24 13:14:57,646]^;INFO^;86^;data_validation.py^;validation_dataset_schema()^;Checking domain values of column 'Outlet_Location_Type'
# [2022-11-24 13:14:57,649]^;INFO^;94^;data_validation.py^;validation_dataset_schema()^;column 'Outlet_Location_Type' has all the required categories and no extra category
# [2022-11-24 13:14:57,650]^;INFO^;86^;data_validation.py^;validation_dataset_schema()^;Checking domain values of column 'Outlet_Type'
# [2022-11-24 13:14:57,652]^;INFO^;94^;data_validation.py^;validation_dataset_schema()^;column 'Outlet_Type' has all the required categories and no extra category
# [2022-11-24 13:14:57,653]^;INFO^;86^;data_validation.py^;validation_dataset_schema()^;Checking domain values of column 'Item_Type'
# [2022-11-24 13:14:57,656]^;INFO^;94^;data_validation.py^;validation_dataset_schema()^;column 'Item_Type' has all the required categories and no extra category
# [2022-11-24 13:14:57,657]^;INFO^;86^;data_validation.py^;validation_dataset_schema()^;Checking domain values of column 'Outlet_Identifier'
# [2022-11-24 13:14:57,658]^;INFO^;94^;data_validation.py^;validation_dataset_schema()^;column 'Outlet_Identifier' has all the required categories and no extra category
# [2022-11-24 13:14:57,658]^;INFO^;95^;data_validation.py^;validation_dataset_schema()^;Data Validation Successful!
# [2022-11-24 13:14:57,659]^;INFO^;98^;data_validation.py^;validation_dataset_schema()^;Data Validation done and stats : True
# [2022-11-24 13:14:58,735]^;INFO^;186^;data_validation.py^;initiate_data_validation()^;Data validation artifact : DataValidationArtifact(schema_file_path='d:\\iNeuron\\ML_projects\\Big_mart_sales\\configs\\schema.yaml', report_file_path='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_validation\\2022-11-24-13-14-54\\report.json', report_page_file_path='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_validation\\2022-11-24-13-14-54\\report.html', is_validated=True, message=' data Validation Performed Successfully')
# [2022-11-24 13:14:58,736]^;INFO^;192^;data_validation.py^;__del__()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Data Validation completed <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#
#
# [2022-11-24 13:14:58,738]^;INFO^;130^;__init__.py^;get_data_transformation_config()^;DataTransformationConfig: DataTransformationConfig(transformed_train_dir='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_transformation\\2022-11-24-13-14-54\\transformed_data\\train', transformed_test_dir='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_transformation\\2022-11-24-13-14-54\\transformed_data\\test', preprocessed_object_file_path='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_transformation\\2022-11-24-13-14-54\\preprocessed\\preprocessed.pkl', transformed_train_file='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_transformation\\2022-11-24-13-14-54\\preprocessed_files\\train_transformed', transformed_test_file='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_transformation\\2022-11-24-13-14-54\\preprocessed_files\\test_transformed')
# [2022-11-24 13:14:58,739]^;INFO^;24^;data_transformation.py^;__init__()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Data Transformation Started <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:14:58,750]^;INFO^;26^;common.py^;read_yaml()^;yaml file: d:\iNeuron\ML_projects\Big_mart_sales\configs\schema.yaml loaded successfully
# [2022-11-24 13:14:58,752]^;INFO^;59^;data_transformation.py^;get_data_transformer_object()^;Categorical columns : ['Item_Identifier', 'Item_Fat_Content', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']
# [2022-11-24 13:14:58,754]^;INFO^;60^;data_transformation.py^;get_data_transformer_object()^;Numerical columns : ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Outlet_age']
# [2022-11-24 13:14:58,755]^;INFO^;109^;data_transformation.py^;initiate_data_transformation()^;Preprocessing object received
# [2022-11-24 13:14:58,758]^;INFO^;111^;data_transformation.py^;initiate_data_transformation()^;obtaining Test and Train files and loading as pandas dataframe
# [2022-11-24 13:14:58,887]^;INFO^;26^;common.py^;read_yaml()^;yaml file: d:\iNeuron\ML_projects\Big_mart_sales\configs\schema.yaml loaded successfully
# [2022-11-24 13:14:58,889]^;INFO^;125^;data_transformation.py^;initiate_data_transformation()^;Seperating input features and target feature from test and train
# [2022-11-24 13:14:58,917]^;INFO^;174^;data_transformation.py^;initiate_data_transformation()^;Starting applying preprocessing object on both files
# [2022-11-24 13:15:00,792]^;INFO^;182^;data_transformation.py^;initiate_data_transformation()^;To check operations performed correctly or not will save this dataframe
# [2022-11-24 13:15:01,029]^;INFO^;231^;data_transformation.py^;initiate_data_transformation()^;Saving transformed training and testing array.
# [2022-11-24 13:15:01,034]^;INFO^;238^;data_transformation.py^;initiate_data_transformation()^;Saving preprocessing object.
# [2022-11-24 13:15:01,041]^;INFO^;252^;data_transformation.py^;initiate_data_transformation()^;Data Transformation artifact : DataTransformationArtifact(is_transformed=True, message='Data Transformation Successful', transformed_train_file_path=WindowsPath('d:/iNeuron/ML_projects/Big_mart_sales/sales/artifact/data_transformation/2022-11-24-13-14-54/transformed_data/train/data.npz'), transformed_test_file_path=WindowsPath('d:/iNeuron/ML_projects/Big_mart_sales/sales/artifact/data_transformation/2022-11-24-13-14-54/transformed_data/test/data.npz'), preprocessed_object_file_path=WindowsPath('d:/iNeuron/ML_projects/Big_mart_sales/sales/artifact/data_transformation/2022-11-24-13-14-54/preprocessed/preprocessed.pkl'), transformed_train_arr_df_sorce='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_transformation\\2022-11-24-13-14-54\\preprocessed_files\\train_transformed\\train_array_df.csv', transformed_test_arr_df_source='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\data_transformation\\2022-11-24-13-14-54\\preprocessed_files\\test_transformed\\test_arry_df.csv')
# [2022-11-24 13:15:01,045]^;INFO^;260^;data_transformation.py^;__del__()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Data Transformation completed <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:15:01,046]^;INFO^;157^;__init__.py^;get_model_trainer_config()^;Model trainer config: ModelTrainerConfig(trained_model_file_path='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\model_trainer\\2022-11-24-13-14-54\\trained_model\\model.pkl', base_accuracy=0.4, model_config_file_path='d:\\iNeuron\\ML_projects\\Big_mart_sales\\configs\\model.yaml')
# [2022-11-24 13:15:01,046]^;INFO^;46^;model_trainer.py^;__init__()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Model trainer log started.<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:15:01,047]^;INFO^;89^;model_trainer.py^;initiate_model_trainer()^;Loading transformed training dataset
# [2022-11-24 13:15:01,048]^;INFO^;93^;model_trainer.py^;initiate_model_trainer()^;Loading transformed testing dataset
# [2022-11-24 13:15:01,050]^;INFO^;97^;model_trainer.py^;initiate_model_trainer()^;Splitting training and testing input and target feature
# [2022-11-24 13:15:01,051]^;INFO^;100^;model_trainer.py^;initiate_model_trainer()^;Extracting model config file path
# [2022-11-24 13:15:01,051]^;INFO^;102^;model_trainer.py^;initiate_model_trainer()^;Initializing model factory class using above model config file: d:\iNeuron\ML_projects\Big_mart_sales\configs\model.yaml
# [2022-11-24 13:15:01,066]^;INFO^;105^;model_trainer.py^;initiate_model_trainer()^;Expected accuracy: 0.4
# [2022-11-24 13:15:01,067]^;INFO^;106^;model_trainer.py^;initiate_model_trainer()^;Initiating operation model selection
# [2022-11-24 13:15:01,068]^;INFO^;291^;model_factory.py^;get_best_model()^;Started Initializing model from config file
# [2022-11-24 13:15:01,069]^;INFO^;144^;model_factory.py^;class_for_name()^;Executing command: from <module 'sklearn.linear_model' from 'd:\\iNeuron\\ML_projects\\Big_mart_sales\\env\\lib\\site-packages\\sklearn\\linear_model\\__init__.py'> import LinearRegression
# [2022-11-24 13:15:01,070]^;INFO^;144^;model_factory.py^;class_for_name()^;Executing command: from <module 'sklearn.linear_model' from 'd:\\iNeuron\\ML_projects\\Big_mart_sales\\env\\lib\\site-packages\\sklearn\\linear_model\\__init__.py'> import Ridge
# [2022-11-24 13:15:01,072]^;INFO^;144^;model_factory.py^;class_for_name()^;Executing command: from <module 'sklearn.linear_model' from 'd:\\iNeuron\\ML_projects\\Big_mart_sales\\env\\lib\\site-packages\\sklearn\\linear_model\\__init__.py'> import Lasso
# [2022-11-24 13:15:01,072]^;INFO^;144^;model_factory.py^;class_for_name()^;Executing command: from <module 'sklearn.linear_model' from 'd:\\iNeuron\\ML_projects\\Big_mart_sales\\env\\lib\\site-packages\\sklearn\\linear_model\\__init__.py'> import ElasticNet
# [2022-11-24 13:15:01,076]^;INFO^;144^;model_factory.py^;class_for_name()^;Executing command: from <module 'sklearn.tree' from 'd:\\iNeuron\\ML_projects\\Big_mart_sales\\env\\lib\\site-packages\\sklearn\\tree\\__init__.py'> import DecisionTreeRegressor
# [2022-11-24 13:15:01,077]^;INFO^;144^;model_factory.py^;class_for_name()^;Executing command: from <module 'sklearn.ensemble' from 'd:\\iNeuron\\ML_projects\\Big_mart_sales\\env\\lib\\site-packages\\sklearn\\ensemble\\__init__.py'> import RandomForestRegressor
# [2022-11-24 13:15:01,078]^;INFO^;144^;model_factory.py^;class_for_name()^;Executing command: from <module 'sklearn.ensemble' from 'd:\\iNeuron\\ML_projects\\Big_mart_sales\\env\\lib\\site-packages\\sklearn\\ensemble\\__init__.py'> import GradientBoostingRegressor
# [2022-11-24 13:15:01,083]^;INFO^;293^;model_factory.py^;get_best_model()^;Initialized model: [InitializedModelDetail(model_serial_number='module_0', model=LinearRegression(), param_grid_search={'fit_intercept': [True, False]}, model_name='sklearn.linear_model.LinearRegression'), InitializedModelDetail(model_serial_number='module_1', model=Ridge(), param_grid_search={'alpha': [1e-08, 0.0001, 0.01, 1, 5, 10, 20, 40, 80], 'fit_intercept': [True, False]}, model_name='sklearn.linear_model.Ridge'), InitializedModelDetail(model_serial_number='module_2', model=Lasso(), param_grid_search={'alpha': [1e-08, 0.0001, 0.01, 1, 5, 10, 20, 40, 80], 'fit_intercept': [True, False]}, model_name='sklearn.linear_model.Lasso'), InitializedModelDetail(model_serial_number='module_3', model=ElasticNet(), param_grid_search={'alpha': [1e-08, 0.0001, 0.01, 1, 5, 10, 20, 40, 80], 'fit_intercept': [True, False], 'l1_ratio': [1e-11, 1e-06, 0.001, 1, 5, 10, 20, 50, 70, 80, 100]}, model_name='sklearn.linear_model.ElasticNet'), InitializedModelDetail(model_serial_number='module_4', model=DecisionTreeRegressor(), param_grid_search={'min_samples_leaf': [1, 2, 3, 4, 5]}, model_name='sklearn.tree.DecisionTreeRegressor'), InitializedModelDetail(model_serial_number='module_5', model=RandomForestRegressor(), param_grid_search={'criterion': ['squared_error', 'absolute_error', 'poisson'], 'max_depth': [3, 5, 7, 10, 15, 25]}, model_name='sklearn.ensemble.RandomForestRegressor'), InitializedModelDetail(model_serial_number='module_6', model=GradientBoostingRegressor(), param_grid_search={'criterion': ['friedman_mse', 'squared_error'], 'loss': ['squared_error', 'absolute_error', 'huber', 'quantile']}, model_name='sklearn.ensemble.GradientBoostingRegressor')]
# [2022-11-24 13:15:01,086]^;INFO^;144^;model_factory.py^;class_for_name()^;Executing command: from <module 'sklearn.model_selection' from 'd:\\iNeuron\\ML_projects\\Big_mart_sales\\env\\lib\\site-packages\\sklearn\\model_selection\\__init__.py'> import GridSearchCV
# {'cv': 4, 'verbose': 2}
# [2022-11-24 13:15:01,088]^;INFO^;157^;model_factory.py^;update_property_of_class()^;Executing:$ GridSearchCV(estimator=LinearRegression(),
#              param_grid={'fit_intercept': [True, False]}).cv=4
# [2022-11-24 13:15:01,090]^;INFO^;157^;model_factory.py^;update_property_of_class()^;Executing:$ GridSearchCV(cv=4, estimator=LinearRegression(),
#              param_grid={'fit_intercept': [True, False]}).verbose=2
# [2022-11-24 13:15:01,090]^;INFO^;221^;model_factory.py^;execute_grid_search_operation()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> f"Training LinearRegression Started." <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Fitting 4 folds for each of 2 candidates, totalling 8 fits
# [CV] END .................................fit_intercept=True; total time=   0.0s
# [CV] END .................................fit_intercept=True; total time=   0.0s
# [CV] END .................................fit_intercept=True; total time=   0.0s
# [CV] END .................................fit_intercept=True; total time=   0.0s
# [CV] END ................................fit_intercept=False; total time=   0.0s
# [CV] END ................................fit_intercept=False; total time=   0.0s
# [CV] END ................................fit_intercept=False; total time=   0.0s
# [CV] END ................................fit_intercept=False; total time=   0.0s
# [2022-11-24 13:15:01,134]^;INFO^;144^;model_factory.py^;class_for_name()^;Executing command: from <module 'sklearn.model_selection' from 'd:\\iNeuron\\ML_projects\\Big_mart_sales\\env\\lib\\site-packages\\sklearn\\model_selection\\__init__.py'> import GridSearchCV
# {'cv': 4, 'verbose': 2}
# [2022-11-24 13:15:01,135]^;INFO^;157^;model_factory.py^;update_property_of_class()^;Executing:$ GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [1e-08, 0.0001, 0.01, 1, 5, 10, 20, 40, 80],
#                          'fit_intercept': [True, False]}).cv=4
# [2022-11-24 13:15:01,137]^;INFO^;157^;model_factory.py^;update_property_of_class()^;Executing:$ GridSearchCV(cv=4, estimator=Ridge(),
#              param_grid={'alpha': [1e-08, 0.0001, 0.01, 1, 5, 10, 20, 40, 80],
#                          'fit_intercept': [True, False]}).verbose=2
# [2022-11-24 13:15:01,138]^;INFO^;221^;model_factory.py^;execute_grid_search_operation()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> f"Training Ridge Started." <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Fitting 4 folds for each of 18 candidates, totalling 72 fits
# [CV] END ....................alpha=1e-08, fit_intercept=True; total time=   0.0s
# [CV] END ....................alpha=1e-08, fit_intercept=True; total time=   0.0s
# [CV] END ....................alpha=1e-08, fit_intercept=True; total time=   0.0s
# [CV] END ....................alpha=1e-08, fit_intercept=True; total time=   0.0s
# [CV] END ...................alpha=1e-08, fit_intercept=False; total time=   0.0s
# [CV] END ...................alpha=1e-08, fit_intercept=False; total time=   0.0s
# [CV] END ...................alpha=1e-08, fit_intercept=False; total time=   0.0s
# [CV] END ...................alpha=1e-08, fit_intercept=False; total time=   0.0s
# [CV] END ...................alpha=0.0001, fit_intercept=True; total time=   0.0s
# [CV] END ...................alpha=0.0001, fit_intercept=True; total time=   0.0s
# [CV] END ...................alpha=0.0001, fit_intercept=True; total time=   0.0s
# [CV] END ...................alpha=0.0001, fit_intercept=True; total time=   0.0s
# [CV] END ..................alpha=0.0001, fit_intercept=False; total time=   0.0s
# [CV] END ..................alpha=0.0001, fit_intercept=False; total time=   0.0s
# [CV] END ..................alpha=0.0001, fit_intercept=False; total time=   0.0s
# [CV] END ..................alpha=0.0001, fit_intercept=False; total time=   0.0s
# [CV] END .....................alpha=0.01, fit_intercept=True; total time=   0.0s
# [CV] END .....................alpha=0.01, fit_intercept=True; total time=   0.0s
# [CV] END .....................alpha=0.01, fit_intercept=True; total time=   0.0s
# [CV] END .....................alpha=0.01, fit_intercept=True; total time=   0.0s
# [CV] END ....................alpha=0.01, fit_intercept=False; total time=   0.0s
# [CV] END ....................alpha=0.01, fit_intercept=False; total time=   0.0s
# [CV] END ....................alpha=0.01, fit_intercept=False; total time=   0.0s
# [CV] END ....................alpha=0.01, fit_intercept=False; total time=   0.0s
# [CV] END ........................alpha=1, fit_intercept=True; total time=   0.0s
# [CV] END ........................alpha=1, fit_intercept=True; total time=   0.0s
# [CV] END ........................alpha=1, fit_intercept=True; total time=   0.0s
# [CV] END ........................alpha=1, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=1, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=1, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=1, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=1, fit_intercept=False; total time=   0.0s
# [CV] END ........................alpha=5, fit_intercept=True; total time=   0.0s
# [CV] END ........................alpha=5, fit_intercept=True; total time=   0.0s
# [CV] END ........................alpha=5, fit_intercept=True; total time=   0.0s
# [CV] END ........................alpha=5, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=5, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=5, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=5, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=5, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=10, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=10, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=10, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=10, fit_intercept=True; total time=   0.0s
# [CV] END ......................alpha=10, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=10, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=10, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=10, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=20, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=20, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=20, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=20, fit_intercept=True; total time=   0.0s
# [CV] END ......................alpha=20, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=20, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=20, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=20, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=40, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=40, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=40, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=40, fit_intercept=True; total time=   0.0s
# [CV] END ......................alpha=40, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=40, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=40, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=40, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=80, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=80, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=80, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=80, fit_intercept=True; total time=   0.0s
# [CV] END ......................alpha=80, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=80, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=80, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=80, fit_intercept=False; total time=   0.0s
# [2022-11-24 13:15:01,313]^;INFO^;144^;model_factory.py^;class_for_name()^;Executing command: from <module 'sklearn.model_selection' from 'd:\\iNeuron\\ML_projects\\Big_mart_sales\\env\\lib\\site-packages\\sklearn\\model_selection\\__init__.py'> import GridSearchCV
# {'cv': 4, 'verbose': 2}
# [2022-11-24 13:15:01,314]^;INFO^;157^;model_factory.py^;update_property_of_class()^;Executing:$ GridSearchCV(estimator=Lasso(),
#              param_grid={'alpha': [1e-08, 0.0001, 0.01, 1, 5, 10, 20, 40, 80],
#                          'fit_intercept': [True, False]}).cv=4
# [2022-11-24 13:15:01,316]^;INFO^;157^;model_factory.py^;update_property_of_class()^;Executing:$ GridSearchCV(cv=4, estimator=Lasso(),
#              param_grid={'alpha': [1e-08, 0.0001, 0.01, 1, 5, 10, 20, 40, 80],
#                          'fit_intercept': [True, False]}).verbose=2
# [2022-11-24 13:15:01,317]^;INFO^;221^;model_factory.py^;execute_grid_search_operation()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> f"Training Lasso Started." <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Fitting 4 folds for each of 18 candidates, totalling 72 fits
# [CV] END ....................alpha=1e-08, fit_intercept=True; total time=   0.0s
# [CV] END ....................alpha=1e-08, fit_intercept=True; total time=   0.0s
# [CV] END ....................alpha=1e-08, fit_intercept=True; total time=   0.0s
# [CV] END ....................alpha=1e-08, fit_intercept=True; total time=   0.0s
# [CV] END ...................alpha=1e-08, fit_intercept=False; total time=   0.0s
# [CV] END ...................alpha=1e-08, fit_intercept=False; total time=   0.0s
# [CV] END ...................alpha=1e-08, fit_intercept=False; total time=   0.0s
# [CV] END ...................alpha=1e-08, fit_intercept=False; total time=   0.0s
# [CV] END ...................alpha=0.0001, fit_intercept=True; total time=   0.0s
# [CV] END ...................alpha=0.0001, fit_intercept=True; total time=   0.0s
# [CV] END ...................alpha=0.0001, fit_intercept=True; total time=   0.0s
# [CV] END ...................alpha=0.0001, fit_intercept=True; total time=   0.0s
# [CV] END ..................alpha=0.0001, fit_intercept=False; total time=   0.0s
# [CV] END ..................alpha=0.0001, fit_intercept=False; total time=   0.0s
# [CV] END ..................alpha=0.0001, fit_intercept=False; total time=   0.0s
# [CV] END ..................alpha=0.0001, fit_intercept=False; total time=   0.0s
# [CV] END .....................alpha=0.01, fit_intercept=True; total time=   0.0s
# [CV] END .....................alpha=0.01, fit_intercept=True; total time=   0.0s
# [CV] END .....................alpha=0.01, fit_intercept=True; total time=   0.0s
# [CV] END .....................alpha=0.01, fit_intercept=True; total time=   0.0s
# [CV] END ....................alpha=0.01, fit_intercept=False; total time=   0.0s
# [CV] END ....................alpha=0.01, fit_intercept=False; total time=   0.0s
# [CV] END ....................alpha=0.01, fit_intercept=False; total time=   0.0s
# [CV] END ....................alpha=0.01, fit_intercept=False; total time=   0.0s
# [CV] END ........................alpha=1, fit_intercept=True; total time=   0.0s
# [CV] END ........................alpha=1, fit_intercept=True; total time=   0.0s
# [CV] END ........................alpha=1, fit_intercept=True; total time=   0.0s
# [CV] END ........................alpha=1, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=1, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=1, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=1, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=1, fit_intercept=False; total time=   0.0s
# [CV] END ........................alpha=5, fit_intercept=True; total time=   0.0s
# [CV] END ........................alpha=5, fit_intercept=True; total time=   0.0s
# [CV] END ........................alpha=5, fit_intercept=True; total time=   0.0s
# [CV] END ........................alpha=5, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=5, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=5, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=5, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=5, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=10, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=10, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=10, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=10, fit_intercept=True; total time=   0.0s
# [CV] END ......................alpha=10, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=10, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=10, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=10, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=20, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=20, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=20, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=20, fit_intercept=True; total time=   0.0s
# [CV] END ......................alpha=20, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=20, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=20, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=20, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=40, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=40, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=40, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=40, fit_intercept=True; total time=   0.0s
# [CV] END ......................alpha=40, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=40, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=40, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=40, fit_intercept=False; total time=   0.0s
# [CV] END .......................alpha=80, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=80, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=80, fit_intercept=True; total time=   0.0s
# [CV] END .......................alpha=80, fit_intercept=True; total time=   0.0s
# [CV] END ......................alpha=80, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=80, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=80, fit_intercept=False; total time=   0.0s
# [CV] END ......................alpha=80, fit_intercept=False; total time=   0.0s
# [2022-11-24 13:15:01,558]^;INFO^;144^;model_factory.py^;class_for_name()^;Executing command: from <module 'sklearn.model_selection' from 'd:\\iNeuron\\ML_projects\\Big_mart_sales\\env\\lib\\site-packages\\sklearn\\model_selection\\__init__.py'> import GridSearchCV
# {'cv': 4, 'verbose': 2}
# [2022-11-24 13:15:01,563]^;INFO^;157^;model_factory.py^;update_property_of_class()^;Executing:$ GridSearchCV(estimator=ElasticNet(),
#              param_grid={'alpha': [1e-08, 0.0001, 0.01, 1, 5, 10, 20, 40, 80],
#                          'fit_intercept': [True, False],
#                          'l1_ratio': [1e-11, 1e-06, 0.001, 1, 5, 10, 20, 50, 70,
#                                       80, 100]}).cv=4
# [2022-11-24 13:15:01,565]^;INFO^;157^;model_factory.py^;update_property_of_class()^;Executing:$ GridSearchCV(cv=4, estimator=ElasticNet(),
#              param_grid={'alpha': [1e-08, 0.0001, 0.01, 1, 5, 10, 20, 40, 80],
#                          'fit_intercept': [True, False],
#                          'l1_ratio': [1e-11, 1e-06, 0.001, 1, 5, 10, 20, 50, 70,
#                                       80, 100]}).verbose=2
# [2022-11-24 13:15:01,565]^;INFO^;221^;model_factory.py^;execute_grid_search_operation()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> f"Training ElasticNet Started." <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Fitting 4 folds for each of 198 candidates, totalling 792 fits
# [CV] END ....alpha=1e-08, fit_intercept=True, l1_ratio=1e-11; total time=   0.0s
# [CV] END ....alpha=1e-08, fit_intercept=True, l1_ratio=1e-11; total time=   0.0s
# [CV] END ....alpha=1e-08, fit_intercept=True, l1_ratio=1e-11; total time=   0.0s
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.421e+09, tolerance: 1.526e+06
#
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.437e+09, tolerance: 1.519e+06
#
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.342e+09, tolerance: 1.506e+06
#
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.345e+09, tolerance: 1.499e+06
# [CV] END ....alpha=1e-08, fit_intercept=True, l1_ratio=1e-11; total time=   0.0s
# [CV] END ....alpha=1e-08, fit_intercept=True, l1_ratio=1e-06; total time=   0.0s
# [CV] END ....alpha=1e-08, fit_intercept=True, l1_ratio=1e-06; total time=   0.0s
# [CV] END ....alpha=1e-08, fit_intercept=True, l1_ratio=1e-06; total time=   0.0s
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.004e+09, tolerance: 1.526e+06
#
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.905e+09, tolerance: 1.519e+06
#
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.160e+09, tolerance: 1.506e+06
#
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.170e+09, tolerance: 1.499e+06
# [CV] END ....alpha=1e-08, fit_intercept=True, l1_ratio=1e-06; total time=   0.0s
# [CV] END ....alpha=1e-08, fit_intercept=True, l1_ratio=0.001; total time=   0.0s
# [CV] END ....alpha=1e-08, fit_intercept=True, l1_ratio=0.001; total time=   0.0s
# [CV] END ....alpha=1e-08, fit_intercept=True, l1_ratio=0.001; total time=   0.0s
# [CV] END ....alpha=1e-08, fit_intercept=True, l1_ratio=0.001; total time=   0.0s
# [CV] END ........alpha=1e-08, fit_intercept=True, l1_ratio=1; total time=   0.0s
# [CV] END ........alpha=1e-08, fit_intercept=True, l1_ratio=1; total time=   0.0s
# [CV] END ........alpha=1e-08, fit_intercept=True, l1_ratio=1; total time=   0.0s
# [CV] END ........alpha=1e-08, fit_intercept=True, l1_ratio=1; total time=   0.0s
# [CV] END ........alpha=1e-08, fit_intercept=True, l1_ratio=5; total time=   0.0s
# [CV] END ........alpha=1e-08, fit_intercept=True, l1_ratio=5; total time=   0.0s
# [CV] END ........alpha=1e-08, fit_intercept=True, l1_ratio=5; total time=   0.0s
# [CV] END ........alpha=1e-08, fit_intercept=True, l1_ratio=5; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=10; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=10; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=10; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=10; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=20; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=20; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=20; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=20; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=50; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=50; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=50; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=50; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=70; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=70; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=70; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=70; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=80; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=80; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=80; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=True, l1_ratio=80; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=True, l1_ratio=100; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=True, l1_ratio=100; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=True, l1_ratio=100; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=True, l1_ratio=100; total time=   0.0s
# [CV] END ...alpha=1e-08, fit_intercept=False, l1_ratio=1e-11; total time=   0.0s
# [CV] END ...alpha=1e-08, fit_intercept=False, l1_ratio=1e-11; total time=   0.0s
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.590e+10, tolerance: 4.047e+06
#
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.595e+10, tolerance: 4.029e+06
#
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.566e+10, tolerance: 3.963e+06
# [CV] END ...alpha=1e-08, fit_intercept=False, l1_ratio=1e-11; total time=   0.0s
# [CV] END ...alpha=1e-08, fit_intercept=False, l1_ratio=1e-11; total time=   0.0s
# [CV] END ...alpha=1e-08, fit_intercept=False, l1_ratio=1e-06; total time=   0.0s
# [CV] END ...alpha=1e-08, fit_intercept=False, l1_ratio=1e-06; total time=   0.0s
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.561e+10, tolerance: 3.932e+06
#
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.542e+10, tolerance: 4.047e+06
#
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.450e+10, tolerance: 4.029e+06
#
# d:\iNeuron\ML_projects\Big_mart_sales\env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.456e+10, tolerance: 3.963e+06
# [CV] END ...alpha=1e-08, fit_intercept=False, l1_ratio=1e-06; total time=   0.0s
# [CV] END ...alpha=1e-08, fit_intercept=False, l1_ratio=1e-06; total time=   0.0s
# [CV] END ...alpha=1e-08, fit_intercept=False, l1_ratio=0.001; total time=   0.0s
# [CV] END ...alpha=1e-08, fit_intercept=False, l1_ratio=0.001; total time=   0.0s
# [CV] END ...alpha=1e-08, fit_intercept=False, l1_ratio=0.001; total time=   0.0s
# [CV] END ...alpha=1e-08, fit_intercept=False, l1_ratio=0.001; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=False, l1_ratio=1; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=False, l1_ratio=1; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=False, l1_ratio=1; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=False, l1_ratio=1; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=False, l1_ratio=5; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=False, l1_ratio=5; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=False, l1_ratio=5; total time=   0.0s
# [CV] END .......alpha=1e-08, fit_intercept=False, l1_ratio=5; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=10; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=10; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=10; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=10; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=20; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=20; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=20; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=20; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=50; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=50; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=50; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=50; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=70; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=70; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=70; total time=   0.0s
# [CV] END ......alpha=1e-08, fit_intercept=False, l1_ratio=70; total time=   0.0s
# ...
# [CV] END ........criterion=friedman_mse, loss=absolute_error; total time=   0.5s
# [CV] END ........criterion=friedman_mse, loss=absolute_error; total time=   0.5s
# [CV] END ........criterion=friedman_mse, loss=absolute_error; total time=   0.5s
# [CV] END ........criterion=friedman_mse, loss=absolute_error; total time=   0.5s
# [CV] END .................criterion=friedman_mse, loss=huber; total time=   0.6s
# [CV] END .................criterion=friedman_mse, loss=huber; total time=   0.6s
# [CV] END .................criterion=friedman_mse, loss=huber; total time=   0.6s
# [CV] END .................criterion=friedman_mse, loss=huber; total time=   0.6s
# [CV] END ..............criterion=friedman_mse, loss=quantile; total time=   0.5s
# [CV] END ..............criterion=friedman_mse, loss=quantile; total time=   0.5s
# [CV] END ..............criterion=friedman_mse, loss=quantile; total time=   0.5s
# [CV] END ..............criterion=friedman_mse, loss=quantile; total time=   0.5s
# [CV] END ........criterion=squared_error, loss=squared_error; total time=   0.3s
# [CV] END ........criterion=squared_error, loss=squared_error; total time=   0.3s
# [CV] END ........criterion=squared_error, loss=squared_error; total time=   0.3s
# [CV] END ........criterion=squared_error, loss=squared_error; total time=   0.3s
# [CV] END .......criterion=squared_error, loss=absolute_error; total time=   0.5s
# [CV] END .......criterion=squared_error, loss=absolute_error; total time=   0.5s
# [CV] END .......criterion=squared_error, loss=absolute_error; total time=   0.5s
# [CV] END .......criterion=squared_error, loss=absolute_error; total time=   0.5s
# [CV] END ................criterion=squared_error, loss=huber; total time=   0.6s
# [CV] END ................criterion=squared_error, loss=huber; total time=   0.6s
# [CV] END ................criterion=squared_error, loss=huber; total time=   0.6s
# [CV] END ................criterion=squared_error, loss=huber; total time=   0.6s
# [CV] END .............criterion=squared_error, loss=quantile; total time=   0.5s
# [CV] END .............criterion=squared_error, loss=quantile; total time=   0.5s
# [CV] END .............criterion=squared_error, loss=quantile; total time=   0.5s
# [CV] END .............criterion=squared_error, loss=quantile; total time=   0.5s
# [2022-11-24 13:25:43,726]^;INFO^;279^;model_factory.py^;get_best_model_from_grid_searched_best_model_list()^;Acceptable model found:GridSearchedBestModel(model_serial_number='module_0', model=LinearRegression(), best_model=LinearRegression(), best_parameters={'fit_intercept': True}, best_score=0.5500580047885928)
# [2022-11-24 13:25:43,727]^;INFO^;279^;model_factory.py^;get_best_model_from_grid_searched_best_model_list()^;Acceptable model found:GridSearchedBestModel(model_serial_number='module_1', model=Ridge(), best_model=Ridge(alpha=10), best_parameters={'alpha': 10, 'fit_intercept': True}, best_score=0.5500609160375367)
# [2022-11-24 13:25:43,728]^;INFO^;279^;model_factory.py^;get_best_model_from_grid_searched_best_model_list()^;Acceptable model found:GridSearchedBestModel(model_serial_number='module_2', model=Lasso(), best_model=Lasso(alpha=5), best_parameters={'alpha': 5, 'fit_intercept': True}, best_score=0.5500935534796156)
# [2022-11-24 13:25:43,729]^;INFO^;279^;model_factory.py^;get_best_model_from_grid_searched_best_model_list()^;Acceptable model found:GridSearchedBestModel(model_serial_number='module_5', model=RandomForestRegressor(), best_model=RandomForestRegressor(criterion='poisson', max_depth=5), best_parameters={'criterion': 'poisson', 'max_depth': 5}, best_score=0.5921899228713543)
# [2022-11-24 13:25:43,730]^;INFO^;284^;model_factory.py^;get_best_model_from_grid_searched_best_model_list()^;Best model: GridSearchedBestModel(model_serial_number='module_5', model=RandomForestRegressor(), best_model=RandomForestRegressor(criterion='poisson', max_depth=5), best_parameters={'criterion': 'poisson', 'max_depth': 5}, best_score=0.5921899228713543)
# [2022-11-24 13:25:43,731]^;INFO^;108^;model_trainer.py^;initiate_model_trainer()^;Extracting trained model list.
# [2022-11-24 13:25:43,731]^;INFO^;111^;model_trainer.py^;initiate_model_trainer()^;Evaluating all trained model on training and testing dataset both
# [2022-11-24 13:25:43,733]^;INFO^;52^;model_factory.py^;evaluate_regression_model()^;-+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+- all models in model_list:[GridSearchedBestModel(model_serial_number='module_5', model=RandomForestRegressor(), best_model=RandomForestRegressor(criterion='poisson', max_depth=5), best_parameters={'criterion': 'poisson', 'max_depth': 5}, best_score=0.5921899228713543)] -+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+-
# [2022-11-24 13:25:43,734]^;INFO^;54^;model_factory.py^;evaluate_regression_model()^;-+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+- type: <class 'BigMartSales.entity.model_factory.GridSearchedBestModel'> item in model_list:GridSearchedBestModel(model_serial_number='module_5', model=RandomForestRegressor(), best_model=RandomForestRegressor(criterion='poisson', max_depth=5), best_parameters={'criterion': 'poisson', 'max_depth': 5}, best_score=0.5921899228713543) -+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+-
# [2022-11-24 13:25:43,735]^;INFO^;59^;model_factory.py^;evaluate_regression_model()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Started evaluating model: [GridSearchedBestModel] <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:25:43,736]^;INFO^;61^;model_factory.py^;evaluate_regression_model()^;-+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+- best_model parameter:RandomForestRegressor(criterion='poisson', max_depth=5) -+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+-
# [2022-11-24 13:25:43,788]^;INFO^;84^;model_factory.py^;evaluate_regression_model()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Score <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:25:43,789]^;INFO^;85^;model_factory.py^;evaluate_regression_model()^;Train Score		 Test Score		 Average Score
# [2022-11-24 13:25:43,789]^;INFO^;86^;model_factory.py^;evaluate_regression_model()^;0.606348065653284		 0.616857454074069		0.6115576132210242
# [2022-11-24 13:25:43,790]^;INFO^;88^;model_factory.py^;evaluate_regression_model()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Loss <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:25:43,790]^;INFO^;89^;model_factory.py^;evaluate_regression_model()^;Diff test train accuracy: [0.01050938842078497].
# [2022-11-24 13:25:43,792]^;INFO^;90^;model_factory.py^;evaluate_regression_model()^;Train root mean squared error: [1079.0932291768734].
# [2022-11-24 13:25:43,793]^;INFO^;91^;model_factory.py^;evaluate_regression_model()^;Test root mean squared error: [1020.4753652460225].
# [2022-11-24 13:25:43,794]^;INFO^;107^;model_factory.py^;evaluate_regression_model()^;Acceptable model found MetricInfoArtifact(model_name="GridSearchedBestModel(model_serial_number='module_5', model=RandomForestRegressor(), best_model=RandomForestRegressor(criterion='poisson', max_depth=5), best_parameters={'criterion': 'poisson', 'max_depth': 5}, best_score=0.5921899228713543)", model_object=RandomForestRegressor(criterion='poisson', max_depth=5), train_rmse=1079.0932291768734, test_rmse=1020.4753652460225, train_accuracy=0.606348065653284, test_accuracy=0.616857454074069, model_accuracy=0.6115576132210242, index_number=0).
# [2022-11-24 13:25:43,794]^;INFO^;116^;model_trainer.py^;initiate_model_trainer()^;Best found model on both training and testing dataset.
# [2022-11-24 13:25:43,796]^;INFO^;122^;model_trainer.py^;initiate_model_trainer()^;Saving model at path: d:\iNeuron\ML_projects\Big_mart_sales\sales\artifact\model_trainer\2022-11-24-13-14-54\trained_model\model.pkl
# [2022-11-24 13:25:43,840]^;INFO^;132^;model_trainer.py^;initiate_model_trainer()^;Model Trainer Artifact: ModelTrainerArtifact(is_trained=True, message='Model Trained successfully', trained_model_file_path=WindowsPath('d:/iNeuron/ML_projects/Big_mart_sales/sales/artifact/model_trainer/2022-11-24-13-14-54/trained_model/model.pkl'), train_rmse=1079.0932291768734, test_rmse=1020.4753652460225, train_accuracy=0.606348065653284, test_accuracy=0.616857454074069, model_accuracy=0.6115576132210242)
# [2022-11-24 13:25:43,841]^;INFO^;138^;model_trainer.py^;__del__()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Model trainer log completed.<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:25:43,842]^;INFO^;174^;__init__.py^;get_model_evaluation_config()^;Model Evaluation Config: ModelEvaluationConfig(model_evaluation_file_path='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\model_evaluation\\model_evaluation.yaml', time_stamp='2022-11-24-13-14-54').
# [2022-11-24 13:25:43,843]^;INFO^;21^;model_evaluation.py^;__init__()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Model Evaluation log started.<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:25:43,853]^;INFO^;26^;common.py^;read_yaml()^;yaml file: d:\iNeuron\ML_projects\Big_mart_sales\configs\schema.yaml loaded successfully
# [2022-11-24 13:25:43,875]^;INFO^;26^;common.py^;read_yaml()^;yaml file: d:\iNeuron\ML_projects\Big_mart_sales\configs\schema.yaml loaded successfully
# [2022-11-24 13:25:43,889]^;INFO^;26^;common.py^;read_yaml()^;yaml file: d:\iNeuron\ML_projects\Big_mart_sales\configs\schema.yaml loaded successfully
# [2022-11-24 13:25:43,915]^;INFO^;187^;model_evaluation.py^;initiate_model_evaluation()^;Converting target column into numpy array.
# [2022-11-24 13:25:43,916]^;INFO^;190^;model_evaluation.py^;initiate_model_evaluation()^;Conversion completed target column into numpy array.
# [2022-11-24 13:25:43,918]^;INFO^;26^;common.py^;read_yaml()^;yaml file: d:\iNeuron\ML_projects\Big_mart_sales\sales\artifact\model_evaluation\model_evaluation.yaml loaded successfully
# [2022-11-24 13:25:43,928]^;INFO^;52^;model_factory.py^;evaluate_regression_model()^;-+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+- all models in model_list:[RandomForestRegressor(), RandomForestRegressor()] -+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+-
# [2022-11-24 13:25:43,929]^;INFO^;54^;model_factory.py^;evaluate_regression_model()^;-+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+- type: <class 'BigMartSales.components.model_trainer.salesEstimatorModel'> item in model_list:RandomForestRegressor() -+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+-
# [2022-11-24 13:25:43,930]^;INFO^;54^;model_factory.py^;evaluate_regression_model()^;-+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+- type: <class 'BigMartSales.components.model_trainer.salesEstimatorModel'> item in model_list:RandomForestRegressor() -+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+-
# [2022-11-24 13:25:43,930]^;INFO^;59^;model_factory.py^;evaluate_regression_model()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Started evaluating model: [salesEstimatorModel] <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:25:45,506]^;INFO^;84^;model_factory.py^;evaluate_regression_model()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Score <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:25:45,506]^;INFO^;85^;model_factory.py^;evaluate_regression_model()^;Train Score		 Test Score		 Average Score
# [2022-11-24 13:25:45,507]^;INFO^;86^;model_factory.py^;evaluate_regression_model()^;0.606470406677637		 0.6172186821908998		0.6117973406847377
# [2022-11-24 13:25:45,507]^;INFO^;88^;model_factory.py^;evaluate_regression_model()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Loss <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:25:45,508]^;INFO^;89^;model_factory.py^;evaluate_regression_model()^;Diff test train accuracy: [0.01074827551326285].
# [2022-11-24 13:25:45,509]^;INFO^;90^;model_factory.py^;evaluate_regression_model()^;Train root mean squared error: [1078.9255332780967].
# [2022-11-24 13:25:45,510]^;INFO^;91^;model_factory.py^;evaluate_regression_model()^;Test root mean squared error: [1019.9941979566535].
# [2022-11-24 13:25:45,510]^;INFO^;107^;model_factory.py^;evaluate_regression_model()^;Acceptable model found MetricInfoArtifact(model_name='RandomForestRegressor()', model_object=RandomForestRegressor(), train_rmse=1078.9255332780967, test_rmse=1019.9941979566535, train_accuracy=0.606470406677637, test_accuracy=0.6172186821908998, model_accuracy=0.6117973406847377, index_number=0).
# [2022-11-24 13:25:45,511]^;INFO^;59^;model_factory.py^;evaluate_regression_model()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Started evaluating model: [salesEstimatorModel] <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:25:47,164]^;INFO^;84^;model_factory.py^;evaluate_regression_model()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Score <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:25:47,165]^;INFO^;85^;model_factory.py^;evaluate_regression_model()^;Train Score		 Test Score		 Average Score
# [2022-11-24 13:25:47,165]^;INFO^;86^;model_factory.py^;evaluate_regression_model()^;0.606348065653284		 0.616857454074069		0.6115576132210242
# [2022-11-24 13:25:47,166]^;INFO^;88^;model_factory.py^;evaluate_regression_model()^;>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Loss <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# [2022-11-24 13:25:47,167]^;INFO^;89^;model_factory.py^;evaluate_regression_model()^;Diff test train accuracy: [0.01050938842078497].
# [2022-11-24 13:25:47,167]^;INFO^;90^;model_factory.py^;evaluate_regression_model()^;Train root mean squared error: [1079.0932291768734].
# [2022-11-24 13:25:47,169]^;INFO^;91^;model_factory.py^;evaluate_regression_model()^;Test root mean squared error: [1020.4753652460225].
# [2022-11-24 13:25:47,171]^;INFO^;211^;model_evaluation.py^;initiate_model_evaluation()^;Model evaluation completed. model metric artifact: MetricInfoArtifact(model_name='RandomForestRegressor()', model_object=RandomForestRegressor(), train_rmse=1078.9255332780967, test_rmse=1019.9941979566535, train_accuracy=0.606470406677637, test_accuracy=0.6172186821908998, model_accuracy=0.6117973406847377, index_number=0)
# [2022-11-24 13:25:47,171]^;INFO^;226^;model_evaluation.py^;initiate_model_evaluation()^;Trained model is no better than existing model hence not accepting trained model
# [2022-11-24 13:25:47,172]^;INFO^;235^;model_evaluation.py^;__del__()^;====================Model Evaluation log completed.====================
# [2022-11-24 13:25:47,173]^;INFO^;162^;__init__.py^;run_pipeline()^;Trained model rejected.
# [2022-11-24 13:25:47,174]^;INFO^;163^;__init__.py^;run_pipeline()^;Pipeline completed.
# [2022-11-24 13:25:47,174]^;INFO^;177^;__init__.py^;run_pipeline()^;Pipeline experiment: Experiment(experiment_id='be7cc610-421c-4d84-abdb-4eb0bae5c893', initialization_timestamp='2022-11-24-13-14-54', artifact_time_stamp='2022-11-24-13-14-54', running_status=False, start_time=datetime.datetime(2022, 11, 24, 13, 14, 56, 58078), stop_time=datetime.datetime(2022, 11, 24, 13, 25, 47, 174301), execution_time=datetime.timedelta(seconds=651, microseconds=116223), message='Pipeline has been completed.', experiment_file_path='d:\\iNeuron\\ML_projects\\Big_mart_sales\\sales\\artifact\\experiment\\experiment.csv', accuracy=0.6115576132210242, is_model_accepted=False)
